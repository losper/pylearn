# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_sin(A,f,phi):
    t=np.arange(0,1,0.01)
    y=A*np.cos(2*np.pi*t*f+phi)
    plt.plot(t,y)
    plt.show()
plot_sin(1,1,0)
